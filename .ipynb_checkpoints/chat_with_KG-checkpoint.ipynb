# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import openai
import yaml

from utils import *

import autoKG_full as AKG

# %%
with open("config.yaml", 'r') as stream:
    try:
        params = yaml.safe_load(stream)
    except yaml.YAMLError as exc:
        print(exc)


COMPLETIONS_MODEL = params["OPENAI_API_MODEL"]
EMBEDDING_MODEL = params["EMBEDDING_MODEL"]
my_api_key = params["OPENAI_API_KEY"]
openai.api_key = my_api_key

os.environ['OPENAI_API_KEY'] = my_api_key
OPENAI_API_KEY = os.environ["OPENAI_API_KEY"]

# %%
KG_class_chat = AKG.autoKG(texts=None,
                           source=None,
                           embedding_model=EMBEDDING_MODEL,
                           llm_model=COMPLETIONS_MODEL,
                           openai_api_key=OPENAI_API_KEY,
                           main_topic=None,
                           embedding=False)

# %%
KG_class_chat.load_data(os.path.join('KG_data', 'ref_paper_KG.npy'), include_texts=True)
# Out:
# Successfully load from KG_data\ref_paper_KG.npy

# %%
query = """
Please tell me how to use pre-trained language models to construct a knowledge graph.
"""
record = KG_class_chat.KG_prompt(query,
                                 search_nums=(15, 7, 3, 4, 2),
                                 search_mtd='pair_dist',
                                 use_u=False)
response, keywords_info, ref_info, all_tokens = KG_class_chat.completion_from_record(
                               record,
                               output_tokens=1024,
                               prompt_language='English',
                               show_prompt=False,
                               prompt_keywords=False,
                               include_source=False,
                               )

# %%
print(all_tokens)
print(response)
# Out:
# 9914
# Pre-trained language models (LLMs) can be used to construct knowledge graphs (KGs) by leveraging the knowledge stored in the LLMs. There are several approaches and methods that have been proposed for this purpose.
#
# One approach is to use unsupervised methods, such as MAMA (Minimal User Input Approach) and GPT-RE (GPT-based Relation Extraction). MAMA, proposed by Wang et al., constructs KGs with a single forward pass of the pre-trained LMs over the corpora without any fine-tuning. GPT-RE, proposed by Hao et al., extracts KGs of arbitrary relations from pre-trained LMs using minimal user input. It generates new prompts that can express the target relation in a diverse way and uses the LM to search a large collection of candidate entity pairs, followed by ranking to yield the top entity pairs as the output knowledge.
#
# Another approach is to combine LLMs with graph neural networks (GNNs) for knowledge graph construction. StructGPT, proposed by Trajanoska et al., allows large LMs to directly reason on KGs and perform multi-step question answering. The explicit knowledge contained in the structured KG is utilized for reasoning purposes.
#
# Furthermore, there are methods that focus on distilling knowledge from LLMs to construct KGs. COMET proposes a commonsense transformer model that constructs commonsense KGs by using existing tuples as a seed set of knowledge. BertNet proposes a framework for automatic KG construction empowered by LLMs.
#
# To summarize, pre-trained LLMs can be used to construct KGs by leveraging unsupervised methods, combining LLMs with GNNs, and distilling knowledge from LLMs. These approaches enable the utilization of the knowledge stored in LLMs to enhance the construction and representation of knowledge in KGs.

# %%
KG_class_chat.draw_graph_from_record(record,
                                     node_colors=([0, 1, 1], [0, 1, 0.5], [1, 0.7, 0.75]),
                                     node_shape='o',
                                     edge_color='black',
                                     edge_widths=(2, 0.5),
                                     node_sizes=(500, 150, 50),
                                     font_color='black',
                                     font_size=6,
                                     show_text=False,
                                     save_fig=True,
                                     save_path='KG_outputs/Subgraph_vis.png')
